# %%
import pickle 
import os 
from datetime import datetime
import pandas as pd
import numpy as np

# %%
model_path = r"C:\Users\Admin\Desktop\seoul bike prediction\models\xgboost regressor_r2_0_928_v1.pkl"
model = pickle.load(open(model_path,"rb"))

# %%
data = [[ 1.07807977,  0.22192612,  0.77468297,  1.82005277, -1.26200749,
       -0.25194272, -0.12916836, -0.17535463, -0.22754885, -5.47803337,
       -1.21546253,  1.00873202,  0.30459857,  1.74132735, -0.58152447,
       -0.57866842, -0.39840954, -0.40773843, -0.41815465, -0.40773843,
       -0.40559398, -0.41815465], 
        [-0.65432992,  1.24504573,  0.23697162, -0.5001855 ,  0.56154562,
       -0.28664608, -0.12916836, -0.17535463, -0.22754885,  0.18254726,
        0.94712104,  0.14077827,  0.30459857, -0.57427456,  1.71961809,
       -0.57866842, -0.39840954, -0.40773843, -0.41815465, -0.40773843,
        2.4655198 , -0.41815465]

    
]


prediction = model.predict(data)
list(prediction )
# Out:
# [60.76833, 1120.6365]

# %%
#load sc
sc_dump_path = r"C:\Users\Admin\Desktop\seoul bike prediction\models\scaler.pkl"
sc = pickle.load(open(sc_dump_path,"rb"))

# %%
sc
# Out:
# StandardScaler()

# %%
#user input
date = "10/02/2025"
hour = 21
temperature = 25
humidity = 55 
wind_speed =67
visibility =25
solar_radiation = 0.4
rainfall = 0.7
snowfall = 0.2
seasons = "Winter"
holiday = "No holiday"
functioning_day = "Yes"

# %%
holiday_dic = {"No holiday": 0, "Holiday": 1}
functioning_day = {"No": 0, "Yes": 1}

def get_string_to_datetime(date):
    dt = datetime.strptime(date, "%d/%m/%Y")  # Changed `Date` to `date` (matching the parameter)
    return {"day": dt.day, "month": dt.month, "year": dt.year, "week_day": dt.strftime("%A")}  # Corrected return format to a dictionary

# Example usage
#date = "08/02/2025"  # Replace this with your desired date
str_to_date = get_string_to_datetime(Date)

str_to_date
# Out:
# {'day': 10, 'month': 2, 'year': 2025, 'week_day': 'Monday'}

# %%
# Assuming `str_to_date` is the result of `get_string_to_datetime` function
u_input_list = [
    hour, temperature, humidity, wind_speed, visibility, solar_radiation, rainfall, snowfall,
    holiday_dic[Holiday], functioning_day[Functioning_Day],  # Fixed incorrect indexing
    str_to_date["day"], str_to_date["month"], str_to_date["year"]
]

features_name = [
    "hour", "temperature(°C)", "humidity(%)", "wind speed (m/s)", "visibility (10m)", 
    "solar radiation (MJ/m2)", "rainfall(mm)", "snowfall (cm)", "holiday", "functioning day", 
    "day", "month", "year"
]

df_u_input = pd.DataFrame([u_input_list],columns =features_name)
df_u_input
# Out:
#    hour  temperature(°C)  humidity(%)  wind speed (m/s)  visibility (10m)  \
# 0    21               25           55                67                25
#
#    solar radiation (MJ/m2)  rainfall(mm)  snowfall (cm)  holiday  \
# 0                      0.4           0.7            0.2        0
#
#    functioning day  day  month  year
# 0                1   10      2  2025

# %%
def season_to_df(seasons):
    seasons_cols = ['Spring', 'Summer', 'Winter']
    seasons_data = np.zeros((1, len(seasons_cols)), dtype="int")
    df_seasons = pd.DataFrame(seasons_data, columns=seasons_cols)

    if seasons in seasons_cols:  
        df_seasons[seasons] = 1

    return df_seasons
df_seasons = season_to_df(seasons)
df_seasons
# Out:
#    Spring  Summer  Winter
# 0       0       0       1

# %%
def days_df(week_day):
    days_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Saturday', 'Sunday']
    days_name_data = np.zeros((1, len(days_names)), dtype="int")
    df_days = pd.DataFrame(days_name_data, columns=days_names)
    
    if week_day in days_names:
        df_days[week_day] = 1

    return df_days



df_days = days_df(str_to_date["week_day"])
print(df_days)
# Out:
#    Monday  Tuesday  Wednesday  Thursday  Saturday  Sunday
# 0       1        0          0         0         0       0

# %%
df_for_pred = pd.concat([df_u_input,df_seasons,df_days],axis = 1  )
df_for_pred
# Out:
#    hour  temperature(°C)  humidity(%)  wind speed (m/s)  visibility (10m)  \
# 0    21               25           55                67                25
#
#    solar radiation (MJ/m2)  rainfall(mm)  snowfall (cm)  holiday  \
# 0                      0.4           0.7            0.2        0
#
#    functioning day  ...  year  Spring  Summer  Winter  Monday  Tuesday  \
# 0                1  ...  2025       0       0       1       1        0
#
#    Wednesday  Thursday  Saturday  Sunday
# 0          0         0         0       0
#
# [1 rows x 22 columns]

# %%
#scaling
sc_data_for_pred = sc.transform(df_for_pred )
sc_data_for_pred
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[220], line 2
#       1 #scaling
# ----> 2 sc_data_for_pred = sc.transform(df_for_pred )
#       3 sc_data_for_pred
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\preprocessing\_data.py:1045, in StandardScaler.transform(self, X, copy)
#    1042 check_is_fitted(self)
#    1044 copy = copy if copy is not None else self.copy
# -> 1045 X = self._validate_data(
#    1046     X,
#    1047     reset=False,
#    1048     accept_sparse="csr",
#    1049     copy=copy,
#    1050     dtype=FLOAT_DTYPES,
#    1051     force_writeable=True,
#    1052     force_all_finite="allow-nan",
#    1053 )
#    1055 if sparse.issparse(X):
#    1056     if self.with_mean:
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:608, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     537 def _validate_data(
#     538     self,
#     539     X="no_validation",
#    (...)
#     544     **check_params,
#     545 ):
#     546     """Validate input data and set or check the `n_features_in_` attribute.
#     547
#     548     Parameters
#    (...)
#     606         validated.
#     607     """
# --> 608     self._check_feature_names(X, reset=reset)
#     610     if y is None and self._get_tags()["requires_y"]:
#     611         raise ValueError(
#     612             f"This {self.__class__.__name__} estimator "
#     613             "requires y to be passed, but the target y is None."
#     614         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:535, in BaseEstimator._check_feature_names(self, X, reset)
#     530 if not missing_names and not unexpected_names:
#     531     message += (
#     532         "Feature names must be in the same order as they were in fit.\n"
#     533     )
# --> 535 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - day
# - functioning day
# - holiday
# - hour
# - humidity(%)
# - ...
# Feature names seen at fit time, yet now missing:
# - Day
# - Functioning Day
# - Holiday
# - Hour
# - Humidity(%)
# - ...
